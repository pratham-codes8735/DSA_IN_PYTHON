# %%
'''
this part includes :-

1. Introduction to Functions
2. Defining Functions
3. Calling Functions
4. Function Parameters
5. Default Parameters
6. Variable-Length Arguments
7. Return Statement

'''

# %%
#A function is a block of code that performs a specific task. Functions help in organizing code, reusing code, and
#improving readability.

#Syntax:-

def function_name(parameters):
    '''Docstring'''

    #Function Body

#    return Expression

# %%
#why we practice functions 
num= 24
if num%2 == 0:
    print("num is even")
else:
    print("num is odd")
# Out:
# num is even

# %%
def even_or_odd(num):
    if num%2==0:
        print('the number is even')
    else:
        print('the number is odd')

# %%
even_or_odd(44)
# Out:
# the number is even

# %%
#function with multiple parameters

def add (a,b):
    c= a+b
    return c
add (2,8)
# Out:
# 10

# %%
def add(a,b):
    return a+b

result= add(2,4)
print (result)
# Out:
# 6

# %%
result=add(12,48)
print(result)
# Out:
# 60

# %%
# default parameters

def greet(name='Guest'):
    print(f'Hello {name} welcome to the celebration party')

#greet('Python')
    
greet()
# Out:
# Hello Guest welcome to the celebration party

# %%
#variable length arguments
#positional and keywords arguments

def print_numbers(*args):
    for number in args:
        print(number)
 
print_numbers(1,2,3,4,5,6)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
# keyword arguments

def print_details(**kwargs):
    for key, value in kwargs.items():
        print(f'{key}:{value}')
print_details(name='Pratham' , age='21' , country = 'India')
# Out:
# name:Pratham
# age:21
# country:India

# %%
#return multiple parameters
def multiply (a,b):
    return a*b, a

multiply(2,5)
# Out:
# (10, 2)
